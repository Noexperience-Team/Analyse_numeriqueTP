# %%
# !pip install watermark
# %load_ext watermark
# %watermark --iversions
# Out:
# Collecting watermark
#   Downloading watermark-2.0.2-py2.py3-none-any.whl (5.3 kB)
# Requirement already satisfied: ipython in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from watermark) (7.12.0)
# Requirement already satisfied: pickleshare in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (42.0.1.post20191125)
# Requirement already satisfied: pygments in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (2.5.2)
# Requirement already satisfied: backcall in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (0.1.0)
# Requirement already satisfied: decorator in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (4.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (3.0.3)
# Requirement already satisfied: traitlets>=4.2 in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (0.16.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from ipython->watermark) (4.8.0)
# Requirement already satisfied: wcwidth in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->watermark) (0.1.8)
# Requirement already satisfied: six in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from traitlets>=4.2->ipython->watermark) (1.13.0)
# Requirement already satisfied: ipython-genutils in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from traitlets>=4.2->ipython->watermark) (0.2.0)
# Requirement already satisfied: parso>=0.5.2 in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from jedi>=0.10->ipython->watermark) (0.6.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/bacemabr/anaconda3/envs/chatbot1/lib/python3.6/site-packages (from pexpect; sys_platform != "win32"->ipython->watermark) (0.6.0)
# Installing collected packages: watermark
# Successfully installed watermark-2.0.2
# numpy 1.17.4

# %%
def PR(x,y,c):
    S = []
    n = len(x);
    l=[]
    
    for i in range(len(x)):
        l=[c-xx for xx in x]
        
        for j in range(len(x)):
            if i==j:
                l[j]=1
            else:
                l[j]=l[j]/(x[i]-x[j])
                
        
        S.append(y[i]*np.prod(l))
    return sum(S);

# %%
import numpy as np
X=[1,2,3,4];
Y=[-1,0,2,1];
for i in (X):
    print(PR(X,Y,i))
# Out:
# -1.0
# 0.0
# 2.0
# 1.0

# %%
import matplotlib.pyplot as plt
x=np.linspace(-1,1,20)
f=lambda x:1/(1+x**2)
t=np.linspace(-1,1,100)
y=[f(xx) for xx in x]
pt=[]
for u in range (len(t)):
    pt.append(PR(x,y,t[u]))

plt.plot(t,pt,'r*',x,f(x),'bo',t,f(t),'g')
plt.show()

# %%
x=np.linspace(0,2,3)
import math
f=lambda x:math.pi-math.cos(x/2)+x*math.sqrt(1-(x/2)**2)
t=np.linspace(-1,1,100)
y=[f(xx) for xx in x]
pt=[]
for u in range (len(t)):
    pt.append(PR(x,y,t[u]))
y2=[f(tt) for tt in t]
plt.plot(t,pt,'r*',x,y,'bo',t,y2,'g')
plt.show()

# %%
y3=[y2[i]-pt[i] for i in range(len(y2))]
plt.plot(t,y3,'r')
plt.show()

# %%
fig = plt.figure(figsize=(30,30))
N=7
X=np.linspace(-5,5,N)
f=lambda x: 1./(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
figure=plt.subplot(2,2,1)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=7")

##############################
N=8
X=np.linspace(-5,5,N)
f=lambda x: 1./(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=8")
##############################
N=9
X=np.linspace(-5,5,N)
f=lambda x: 1./(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=9")
##############################
N=10
X=np.linspace(-5,5,N)
f=lambda x: 1./(1+x**2)
Y=f(X)
p=np.polyfit(X,Y,N-1)
t=np.linspace(-5,5,1000)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',X,Y,'ob', t, np.polyval(p,t),'g')
plt.title("Interpolation Equidistante avec N=10")
plt.show()

# %%
import math
def tcheb(a,b,n):
    return [(a+b)/2+(a-b)/2*math.cos((k-1)/(n-1)*math.pi) for k in range(n)]
# Out:
# [-4.698463103929543,
#  -5.0,
#  -4.698463103929543,
#  -3.83022221559489,
#  -2.5000000000000004,
#  -0.8682408883346521,
#  0.8682408883346515,
#  2.499999999999999,
#  3.8302222155948895,
#  4.698463103929542]

# %%
fig = plt.figure(figsize=(30,30))
N=10
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[f(xt) for xt in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title("Interpolation Tchebycheff avec N=10")
##########################################
N=11
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[f(xt) for xt in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title("Interpolation Tchebycheff avec N=11")
##########################################
N=16
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[f(xt) for xt in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title("Interpolation Tchebycheff avec N=16")
##########################################
N=17
f=lambda x: 1/(1+x**2)
Xt=tcheb(-5,5,N)
Yt=[f(xt) for xt in Xt]
pt=np.polyfit(Xt,Yt,N-1)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r',Xt,Yt,'ob', t, np.polyval(pt,t),'g')
plt.title("Interpolation Tchebycheff avec N=17")
plt.show()
# Out:
# /home/bacemabr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RankWarning: Polyfit may be poorly conditioned
#
# /home/bacemabr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RankWarning: Polyfit may be poorly conditioned
#   from ipykernel import kernelapp as app
# /home/bacemabr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: RankWarning: Polyfit may be poorly conditioned
# /home/bacemabr/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: RankWarning: Polyfit may be poorly conditioned

# %%
def intN(x,y):
    m=len(x)
    f=np.zeros(m)
    for k in range(1,m):
        f[k:m+1]=np.array(np.array(y[k:m+1])-np.array(y[k-1:m-1]))/np.array(np.array(x[k:m+1])-np.array(x[0:m-k]))
    return f

# %%
x=[-1,0,2,5]
y=[6,1,3,66]
print(intN(x,y))
# Out:
# [ 0.         -5.          0.66666667 10.5       ]

# %%
def intNval(x,y,t):
    m=len(x)
    p=y[m-1]*np.ones(len(t))
    for k in range(m-2,-1,-1):
       
        p=p*np.array((np.array(t)-x[k]))+y[k]
        
        
    return p

# %%
x=[-1,0,2,5];
y=[6,1,3,66];
t=[0,1,2,3];

f=intNval(x,y,t)
print(f)
# Out:
# [   7. -118.   27.  838.]

# %%
x=[-1,0,2,5];
y=[6,1,3,66];
f=intN(x,y);
plt.plot(x,f,'r',x,y,'ob')
plt.show()

# %%
x=[-1,0,2,5];
y=[6,1,3,66];
t=[0,1,2,3];
p=intNval(x,y,t);
print(p[0])
# Out:
# 7.0
